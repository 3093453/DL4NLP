# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# # load the dataframe

# %%
df = pd.read_csv("/Users/fynn/Uni/DL4NLP/data/Annotationen-Stufe-2.txt", index_col=0)
df.drop(["Seite", "Unnamed: 2",
         "Semantikerweiterung?",
         "Unersetzlich?",
         "Unersetzlich?",
         "sprachlich irregulär?",
         "pointiert?"], axis = 1, inplace = True) # 2x Floskel

df = df[~df.Textstelle.isnull()]
df

df.head()
# Out:
#                                           Textstelle          Metapher?  \
# 0   Bei Beobachtung solchen moralischen Wertes ka...           Metapher
# 1               Die Zellen verschmelzen miteinander.  Metaphernkandidat
# 2   Diese wolle die bittere Auslese, ohne die auc...           Metapher
# 3   Wenn es dem Verfasser gelungen ist, ein gesic...           Metapher
# 4   In Californien ist ebenso die früher dort hei...  Metaphernkandidat
#
#                                                Fokus  \
# 0                               das Horoskop stellen
# 1                                                NaN
# 2                                            bittere
# 3  ein gesichertes Fundament und die ersten Pfeil...
# 4                                                NaN
#
#                                               Rahmen Stärkegrad (A, B, C)  \
# 0                                       einer Nation                    B
# 1                                                NaN                  NaN
# 2                                            Auslese                    A
# 3  die Lösung der hier zur Bearbeitung gestellten...                    A
# 4                                                NaN                  NaN
#
#                                 Begründung/Kommentar Annotator
# 0  Horoskop stellen - bezogen auf Nationen ist da...         B
# 1                                       Fachausdruck         B
# 2  Unauffällig, aber doch metaphorisch: Dass eine...         B
# 3  Bruch, Fokus nicht ohne Bedeutungsverlust erse...         B
# 4  kein Bruch, nur auffälliger Ausdruck, keine Be...         B

# %%
df["Metapher?"].value_counts()
# Out:
# Metaphernkandidat    1785
# Metapher              777
# Unklar                  3
# Grenzfall               1
# Name: Metapher?, dtype: int64

# %%
df["Metapher"] = (df["Metapher?"] == "Metapher").astype(int)
df["Kandidat"] = (df["Metapher?"] == "Metaphernkandidat").astype(int)
df.drop("Metapher?", axis=1, inplace = True)
df
# Out:
#                                              Textstelle  \
# 0      Bei Beobachtung solchen moralischen Wertes ka...
# 1                  Die Zellen verschmelzen miteinander.
# 2      Diese wolle die bittere Auslese, ohne die auc...
# 3      Wenn es dem Verfasser gelungen ist, ein gesic...
# 4      In Californien ist ebenso die früher dort hei...
# ...                                                 ...
# 2579  In ähnlicher Weise sollen noch mehrere andere ...
# 2580  Die Amerikaner folgern, da sie alle Rohmateria...
# 2581  Sie könne bei ihrer jetzigen großen Kraft und ...
# 2582  Schwarze Flecken von Habgier, Raubsucht, Unger...
# 2583  Die Organisation, wie das natürlich ist, geht ...
#
#                                                   Fokus  \
# 0                                  das Horoskop stellen
# 1                                                   NaN
# 2                                               bittere
# 3     ein gesichertes Fundament und die ersten Pfeil...
# 4                                                   NaN
# ...                                                 ...
# 2579                                                NaN
# 2580                              einer turmhohen Mauer
# 2581                         mütterlichen Päppelflasche
# 2582                                                NaN
# 2583                                                NaN
#
#                                                  Rahmen Stärkegrad (A, B, C)  \
# 0                                          einer Nation                    B
# 1                                                   NaN                  NaN
# 2                                               Auslese                    A
# 3     die Lösung der hier zur Bearbeitung gestellten...                    A
# 4                                                   NaN                  NaN
# ...                                                 ...                  ...
# 2579                                                NaN                  NaN
# 2580                                       Schutzzöllen                    A
# 2581                                                Sie                    B
# 2582                                                NaN                  NaN
# 2583                                                NaN                  NaN
#
#                                    Begründung/Kommentar Annotator  Metapher  \
# 0     Horoskop stellen - bezogen auf Nationen ist da...         B         1
# 1                                          Fachausdruck         B         0
# 2     Unauffällig, aber doch metaphorisch: Dass eine...         B         1
# 3     Bruch, Fokus nicht ohne Bedeutungsverlust erse...         B         1
# 4     kein Bruch, nur auffälliger Ausdruck, keine Be...         B         0
# ...                                                 ...       ...       ...
# 2579                                                NaN         B         0
# 2580                                                NaN         B         1
# 2581                                                NaN         B         1
# 2582                                                NaN         B         0
# 2583                                                NaN         B         0
#
#       Kandidat
# 0            0
# 1            1
# 2            0
# 3            0
# 4            1
# ...        ...
# 2579         1
# 2580         0
# 2581         0
# 2582         1
# 2583         1
#
# [2566 rows x 8 columns]

# %%
# example of several occurances
stelle = "Der politische Körper verwendet in beiden Fällen seine meiste Kraft"
stelle +=" auf die Zunahme von Zähnen und Krallen."
clms = ["Textstelle", "Annotator", "Metapher", "Kandidat"]
df.loc[ [stelle in text for text in df["Textstelle"]], clms]
# Out:
#                                              Textstelle Annotator  Metapher  \
# 378    "Der politische Körper verwendet in beiden Fä...         B         1
# 958    "Der politische Körper verwendet in beiden Fä...         K         1
# 1406   "Der politische Körper verwendet in beiden Fä...         A         0
#
#       Kandidat
# 378          0
# 958          0
# 1406         1

# %%
data = df.groupby(["Textstelle"])[["Metapher", "Kandidat"]].sum()
data
# Out:
#                                                     Metapher  Kandidat
# Textstelle
#  "Der politische Körper verwendet in beiden Fäl...         2         1
#  "Immer noch wird durch die protestantische Leh...         0         3
#  "Kein Zweifel", schreibt Alb. Schaeffle 1), vo...         0         3
#  "Mit je weiterem Blick wir die Stoffwelt zu üb...         1         2
#  "Solange das Menschengeschlecht seinen Zerstör...         0         3
# ...                                                      ...       ...
# verlaufs; sie hat Naturforschung in dem von uns...         0         3
# wenn wir uns ein Prinzip denken und auf Grund d...         1         2
# wenn wir von dem schlechten Worte »Rechtsphilof...         2         1
# »Die Macht, die das Kabinett hat, auf die versc...         0         2
# Über die Wirkungen der Kreuzung auf die körperl...         0         2
#
# [806 rows x 2 columns]

# %%
data[["Metapher", "Kandidat"]].sum(axis=1).hist(bins = np.arange(0,10,1)+0.5);
#plt.yscale("log")
plt.xlabel("Annotations per Text");

# %%
erklärung = df.groupby(["Textstelle"])[["Fokus", "Rahmen"]].first()
erklärung[erklärung.isnull()] = np.nan
erklärung
# Out:
#                                                                                   Fokus  \
# Textstelle
#  "Der politische Körper verwendet in beiden Fäl...                   Zähnen und Krallen
#  "Immer noch wird durch die protestantische Leh...                                  NaN
#  "Kein Zweifel", schreibt Alb. Schaeffle 1), vo...                                  NaN
#  "Mit je weiterem Blick wir die Stoffwelt zu üb...  Stoffwelt, verzwergt und entkleidet
#  "Solange das Menschengeschlecht seinen Zerstör...                                  NaN
# ...                                                                                 ...
# verlaufs; sie hat Naturforschung in dem von uns...                                  NaN
# wenn wir uns ein Prinzip denken und auf Grund d...                  verstellbare Puppen
# wenn wir von dem schlechten Worte »Rechtsphilof...                   schwindsüchtig ist
# »Die Macht, die das Kabinett hat, auf die versc...                                  NaN
# Über die Wirkungen der Kreuzung auf die körperl...                                  NaN
#
#                                                                              Rahmen
# Textstelle
#  "Der politische Körper verwendet in beiden Fäl...            der politische Körper
#  "Immer noch wird durch die protestantische Leh...                              NaN
#  "Kein Zweifel", schreibt Alb. Schaeffle 1), vo...                              NaN
#  "Mit je weiterem Blick wir die Stoffwelt zu üb...          unser praktisches Ideal
#  "Solange das Menschengeschlecht seinen Zerstör...                              NaN
# ...                                                                             ...
# verlaufs; sie hat Naturforschung in dem von uns...                              NaN
# wenn wir uns ein Prinzip denken und auf Grund d...  staatliche Menschenverhältnisse
# wenn wir von dem schlechten Worte »Rechtsphilof...             daß eine Philosophie
# »Die Macht, die das Kabinett hat, auf die versc...                              NaN
# Über die Wirkungen der Kreuzung auf die körperl...                              NaN
#
# [806 rows x 2 columns]

# %%
data = data.merge(erklärung, on = "Textstelle")
data.reset_index(inplace = True)
data
# Out:
#                                             Textstelle  Metapher  Kandidat  \
# 0     "Der politische Körper verwendet in beiden Fä...         2         1
# 1     "Immer noch wird durch die protestantische Le...         0         3
# 2     "Kein Zweifel", schreibt Alb. Schaeffle 1), v...         0         3
# 3     "Mit je weiterem Blick wir die Stoffwelt zu ü...         1         2
# 4     "Solange das Menschengeschlecht seinen Zerstö...         0         3
# ..                                                 ...       ...       ...
# 801  verlaufs; sie hat Naturforschung in dem von un...         0         3
# 802  wenn wir uns ein Prinzip denken und auf Grund ...         1         2
# 803  wenn wir von dem schlechten Worte »Rechtsphilo...         2         1
# 804  »Die Macht, die das Kabinett hat, auf die vers...         0         2
# 805  Über die Wirkungen der Kreuzung auf die körper...         0         2
#
#                                    Fokus                           Rahmen
# 0                     Zähnen und Krallen            der politische Körper
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3    Stoffwelt, verzwergt und entkleidet          unser praktisches Ideal
# 4                                    NaN                              NaN
# ..                                   ...                              ...
# 801                                  NaN                              NaN
# 802                  verstellbare Puppen  staatliche Menschenverhältnisse
# 803                   schwindsüchtig ist             daß eine Philosophie
# 804                                  NaN                              NaN
# 805                                  NaN                              NaN
#
# [806 rows x 5 columns]

# %% [markdown]
# ## Compare dataframe to Gold Standard

# %%
gold = pd.read_csv("/Users/fynn/Uni/DL4NLP/data/Annotationen-Stufe-2-GoldStandard.csv", index_col = 0)
gold.drop(["Annotator", "Filename"], axis=1, inplace=True)
gold
# Out:
#                                             Textstelle          Metapher?  \
# 0     Bei Beobachtung solchen moralischen Wertes ka...           Metapher
# 1                 Die Zellen verschmelzen miteinander.  Metaphernkandidat
# 2     das 19. Jahrhundert schließt in dieser Hinsic...           Metapher
# 3     Das Gefühl ist ein Zeuge des jeweilig obwalte...  Metaphernkandidat
# 4     Der erste Fall bricht die Schutzwehr nieder, ...  Metaphernkandidat
# ..                                                 ...                ...
# 653  In ähnlicher Weise sollen noch mehrere andere ...  Metaphernkandidat
# 654  Die Amerikaner folgern, da sie alle Rohmateria...           Metapher
# 655  Sie könne bei ihrer jetzigen großen Kraft und ...  Metaphernkandidat
# 656  Schwarze Flecken von Habgier, Raubsucht, Unger...  Metaphernkandidat
# 657  Die Organisation, wie das natürlich ist, geht ...  Metaphernkandidat
#
#                                             Fokus  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 653                                           NaN
# 654  ['einer turmhohen Mauer', 'turmhohen Mauer']
# 655                                           NaN
# 656                                           NaN
# 657                                           NaN
#
#                                    Rahmen
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 653                                   NaN
# 654  ['Schutzzöllen', 'von Schutzzöllen']
# 655                                   NaN
# 656                                   NaN
# 657                                   NaN
#
# [658 rows x 4 columns]

# %%
# Only 81% of Annotated data is also in the Gold Standard
np.isin(data.Textstelle, gold.Textstelle).mean().round(3)
# Out:
# 0.814

# %%
# But all Gold Labels are also in the 
np.isin(gold.Textstelle, data.Textstelle).mean()
# Out:
# 1.0

# %% [markdown]
# ## Check if there has not been a mistake with the other teams preprocessing
#
# It might be, that the extra Textstellen in the dataframe are just duplicates that are corrupted somehow. They might have an extra space or tab. This makes them the same phrase, but its not possible to join them.
#
# Ideas:
# Clean the data and see if the problem persists
#
# Calculate sentence embeddings and check their cosine similarity. If two different textstellen only differ by a small amount, they are candidates for manual checking.

# %% [markdown]
# ### Clean dataset beforehand and see if the problem persists:

# %%
df = pd.read_csv("/Users/fynn/Uni/DL4NLP/data/Annotationen-Stufe-2.txt", index_col=0)
df.drop(["Seite", "Unnamed: 2",
         "Semantikerweiterung?",
         "Unersetzlich?",
         "Unersetzlich?",
         "sprachlich irregulär?",
         "pointiert?"], axis = 1, inplace = True) # 2x Floskel

df = df[~df.Textstelle.isnull()]
df

df["Metapher"] = (df["Metapher?"] == "Metapher").astype(int)
df["Kandidat"] = (df["Metapher?"] == "Metaphernkandidat").astype(int)
df.drop("Metapher?", axis=1, inplace = True)
df.head()
# Out:
#                                           Textstelle  \
# 0   Bei Beobachtung solchen moralischen Wertes ka...
# 1               Die Zellen verschmelzen miteinander.
# 2   Diese wolle die bittere Auslese, ohne die auc...
# 3   Wenn es dem Verfasser gelungen ist, ein gesic...
# 4   In Californien ist ebenso die früher dort hei...
#
#                                                Fokus  \
# 0                               das Horoskop stellen
# 1                                                NaN
# 2                                            bittere
# 3  ein gesichertes Fundament und die ersten Pfeil...
# 4                                                NaN
#
#                                               Rahmen Stärkegrad (A, B, C)  \
# 0                                       einer Nation                    B
# 1                                                NaN                  NaN
# 2                                            Auslese                    A
# 3  die Lösung der hier zur Bearbeitung gestellten...                    A
# 4                                                NaN                  NaN
#
#                                 Begründung/Kommentar Annotator  Metapher  \
# 0  Horoskop stellen - bezogen auf Nationen ist da...         B         1
# 1                                       Fachausdruck         B         0
# 2  Unauffällig, aber doch metaphorisch: Dass eine...         B         1
# 3  Bruch, Fokus nicht ohne Bedeutungsverlust erse...         B         1
# 4  kein Bruch, nur auffälliger Ausdruck, keine Be...         B         0
#
#    Kandidat
# 0         0
# 1         1
# 2         0
# 3         0
# 4         1

# %%
def eliminate_substring(text, k=22):
    for ii in range(len(text)):
        remaining_text = text[ii:]
        
        jj = k
        while remaining_text[:jj] in remaining_text[jj:]:

            jj+=1
        if jj > k:
            #print(jj)
            return text[:ii] + remaining_text[jj-1:]
    # if we find no substring, just give the text back
    return text

# %%
bins = np.arange(0, 1000, 40)

data = df.copy()

data["Textstelle"].str.len().hist(bins=bins, alpha = 0.7);
print(data["Textstelle"].str.len().mean())

#remove quotes
data["Textstelle"] = data.Textstelle.str.replace('"', '')
data["Textstelle"] = data.Textstelle.str.replace("'", '')
data["Textstelle"] = data.Textstelle.str.replace(r'»', '')
data["Textstelle"] = data.Textstelle.str.replace(r'«', '')
data["Textstelle"] = data.Textstelle.str.replace(r'„', '')
data["Textstelle"] = data.Textstelle.str.replace(r'“', '')

# remove leading/trailing whitespace
data["Textstelle"] = data.Textstelle.str.replace(r'^\s*', "")
data["Textstelle"] = data.Textstelle.str.replace(r'\s\s*', " ")
data["Textstelle"] = data.Textstelle.str.replace(r'[ \t]+$', "")

#remove digits
data["Textstelle"] = data.Textstelle.str.replace(r'\d\.', '')
data["Textstelle"] = data.Textstelle.str.replace(r'\d', '')

# remove brackets:
data["Textstelle"] = data.Textstelle.str.replace(r'\[', '')
data["Textstelle"] = data.Textstelle.str.replace(r'\]', '')
data["Textstelle"] = data.Textstelle.str.replace(r'\(', '')
data["Textstelle"] = data.Textstelle.str.replace(r'\)', '')

# remove special characters
# YES, we remove dots. But they need to be added again at the end
#data["Textstelle"] = data.Textstelle.str.replace(r'.', '')
data["Textstelle"] = data.Textstelle.str.replace(r':', '')
data["Textstelle"] = data.Textstelle.str.replace(r';', '')
data["Textstelle"] = data.Textstelle.str.replace(r'— ', '')
data["Textstelle"] = data.Textstelle.str.replace(r'—', '')
data["Textstelle"] = data.Textstelle.str.replace(r'- ', '') # linebreak extension
data["Textstelle"] = data.Textstelle.str.replace(r'-', '')
data["Textstelle"] = data.Textstelle.str.replace(r'_', '')

# make sure Commas come after a word:
data["Textstelle"] = data.Textstelle.str.replace(r' ,', ',')

# Roman numerals
data["Textstelle"] = data.Textstelle.str.replace(r'^I{0,3}V{0,1}I{0,3} ', "")
data["Textstelle"] = data.Textstelle.str.replace(r'^I{0,1}X{1,2}I{0,3} ', "")





data["Kürzungen"] = 0
for i in range(6):
    new_data = data["Textstelle"].apply(eliminate_substring)
    data["Kürzungen"] += (data["Textstelle"] != new_data)
    data["Textstelle"] = new_data

data["Textstelle"].str.len().hist(bins=bins, alpha = 0.7);
print(data["Textstelle"].str.len().mean())
# Out:
# 270.0565081839439
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'^\s*', "")
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'\s\s*', " ")
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:19: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'[ \t]+$', "")
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'\d\.', '')
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:23: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'\d', '')
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'\[', '')
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:27: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'\]', '')
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:28: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'\(', '')
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:29: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'\)', '')
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'^I{0,3}V{0,1}I{0,3} ', "")
# /var/folders/j4/qmf6qmvd1gv0nctgx3m6jm3r0000gn/T/ipykernel_19124/801797471.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["Textstelle"] = data.Textstelle.str.replace(r'^I{0,1}X{1,2}I{0,3} ', "")
# 246.61106780982072

# %%
data = data.groupby(["Textstelle"])[["Metapher", "Kandidat"]].sum()
data = data.reset_index()
data
# Out:
#                                             Textstelle  Metapher  Kandidat
# 0    Aber auch von diesem Extrem abgesehen, werden ...         0         4
# 1    Aber das Licht der Selektionstheorie reicht no...         1         2
# 2    Aber das Unternehmen erwies sich als ebenso nu...         0         2
# 3    Aber das bedeutendste Ereignis war doch die Ge...         2         1
# 4    Aber der Selbsterhaltungstrieb ist ein ebenso ...         0         3
# ..                                                 ...       ...       ...
# 801  wenn wir von dem schlechten Worte Rechtsphilof...         2         1
# 802  Über die Wirkungen der Kreuzung auf die körper...         0         2
# 803  Überall machen sich starke Bestrebungen gelten...         4         0
# 804  Übrigens haben wir bereits im  Kapitel S. gese...         1         2
# 805  … und wie es darum zu jener Zeit, als die Anat...         0         3
#
# [806 rows x 3 columns]

# %% [markdown]
# ## cleaning seems to change nothing!!!
#
# ## Cosine similarites:

# %%
rnd = np.random.choice(len(data), 5)

for n in rnd:
    print(n)
    print(data.loc[n, "Textstelle"])
    print()
# Out:
# 718
# Was tabu ist und bleibt, hätte dann – auf sich konzentriert und pars pro toto – die der Welt ursprünglich anhaftende Gesamtfärbung einer unbestimmten Umweltfreundlichkeit zu vertreten, wohl auch hier und da im Dienst des Bestehenden zu simulieren.
#
# 597
# Religionsgeschichtlich gesehen, ist es Einengung einer diffus ausgebreiteten Qualität von Unheimlichkeit und Ungefügigkeit auf Enklaven strikt sanktionierter Begrenzung.
#
# 93
# Dann bleiben sie voraussichtlich unverheiratet, und die guten Anlagen werden nicht fortgepflanzt.
#
# 608
# Sicherlich ist durch die vereinigte Arbeit vieler Forscher bedeutendes zur Aufklärung dieses geheimnisvollen und reizvollen Problems geschehen daß wir aber heute bereits vor einer gesicherten Lösung desselben stehen, wird niemand zu behaupten wagen, der die Zickzackwege der Forschung auf diesem Gebiete in letzter Zeit verfolgt hat.
#
# 181
# Der Geist der alten Horde gens protestiert gegen das Territorialitätsprinzip des modernen Staates.

# %%
data.loc[709, "Textstelle"]
# Out:
# 'Was aber in Erstaunen setzen muß und ein Streiflicht auf die Unsicherheit der Historischen Schule hinsichtlich der Empirie als Grundlage ihrer Methode wirft, ist, daß einer ihrer ersten Köpfe sich diesem anmaßlichen Satze der aprioristischen Philosophen unterwarf es ist G. F. Puchta, der sich dahin äußert, daß die Jurisprudenz den Begriff des Rechts nur von der Philosophie überkommen könne.'

# %%
data.loc[409]
# Out:
# Textstelle    Feiglinge zu Hause, aber Löwen der übrigen Wel...
# Metapher                                                      0
# Kandidat                                                      3
# Name: 409, dtype: object
